# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# %%
#  Import and read the flights_data.csv.
flights_df = pd.read_csv("flights_data_df.csv")
flights_df.head()

# %%
flights_df["Is_Delayed"] = None
flights_df.loc[flights_df["DepDelayMinutes"] == 0, "Is_Delayed"] = "1"
flights_df.loc[flights_df["DepDelayMinutes"] > 0, "Is_Delayed"] = "0"

# %%
flights_df.head()

# %%
# Dropping columns
flights_df.drop(['Origin', 'Dest', 'Unnamed: 0', 'Cancelled', 'CarrierDelay', 'WeatherDelay', "NASDelay", 'SecurityDelay', 'LateAircraftDelay', 'FirstDepTime', 'CancellationCode'], axis=1)

# %%
flights_df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek Operating_Airline  Origin  \
# 0           0  2021      1           2          6                 9E    CVG
# 1           1  2021      1           3          7                 9E    CVG
# 2           2  2021      1           4          1                 9E    CVG
# 3           3  2021      1           7          4                 9E    CVG
# 4           4  2021      1           8          5                 9E    CVG
#
#   Dest  CRSDepTime  DepTime  ...  CancellationCode  CRSElapsedTime  \
# 0  BOS         730    733.0  ...               NaN           129.0
# 1  BOS         730    727.0  ...               NaN           129.0
# 2  BOS         730    737.0  ...               NaN           129.0
# 3  BOS        1715   1710.0  ...               NaN           117.0
# 4  BOS        1715   1711.0  ...               NaN           117.0
#
#    ActualElapsedTime  CarrierDelay WeatherDelay  NASDelay  SecurityDelay  \
# 0              114.0           NaN          NaN       NaN            NaN
# 1              117.0           NaN          NaN       NaN            NaN
# 2              121.0           NaN          NaN       NaN            NaN
# 3              121.0           NaN          NaN       NaN            NaN
# 4              135.0           NaN          NaN       NaN            NaN
#
#    LateAircraftDelay  FirstDepTime  Is_Delayed
# 0                NaN           NaN           0
# 1                NaN           NaN           1
# 2                NaN           NaN           0
# 3                NaN           NaN           1
# 4                NaN           NaN           1
#
# [5 rows x 24 columns]

# %%
pd.get_dummies(flights_df, columns=['Operating_Airline '])
# Out:
#           Unnamed: 0  Year  Month  DayofMonth  DayOfWeek Origin Dest  \
# 0                  0  2021      1           2          6    CVG  BOS
# 1                  1  2021      1           3          7    CVG  BOS
# 2                  2  2021      1           4          1    CVG  BOS
# 3                  3  2021      1           7          4    CVG  BOS
# 4                  4  2021      1           8          5    CVG  BOS
# ...              ...   ...    ...         ...        ...    ...  ...
# 10390184      618785  2022      7           1          5    ALB  EWR
# 10390185      618786  2022      7           1          5    AVL  EWR
# 10390186      618787  2022      7           1          5    ALB  EWR
# 10390187      618788  2022      7           1          5    BNA  EWR
# 10390188      618789  2022      7           1          5    BOS  EWR
#
#           CRSDepTime  DepTime  DepDelayMinutes  ...  Operating_Airline _NK  \
# 0                730    733.0              3.0  ...                      0
# 1                730    727.0              0.0  ...                      0
# 2                730    737.0              7.0  ...                      0
# 3               1715   1710.0              0.0  ...                      0
# 4               1715   1711.0              0.0  ...                      0
# ...              ...      ...              ...  ...                    ...
# 10390184        1500   1516.0             16.0  ...                      0
# 10390185        1246   1236.0              0.0  ...                      0
# 10390186        1201   1153.0              0.0  ...                      0
# 10390187        1430   1458.0             28.0  ...                      0
# 10390188        1605   1904.0            179.0  ...                      0
#
#           Operating_Airline _OH  Operating_Airline _OO Operating_Airline _PT  \
# 0                             0                      0                     0
# 1                             0                      0                     0
# 2                             0                      0                     0
# 3                             0                      0                     0
# 4                             0                      0                     0
# ...                         ...                    ...                   ...
# 10390184                      0                      0                     0
# 10390185                      0                      0                     0
# 10390186                      0                      0                     0
# 10390187                      0                      0                     0
# 10390188                      0                      0                     0
#
#           Operating_Airline _QX  Operating_Airline _UA  Operating_Airline _WN  \
# 0                             0                      0                      0
# 1                             0                      0                      0
# 2                             0                      0                      0
# 3                             0                      0                      0
# 4                             0                      0                      0
# ...                         ...                    ...                    ...
# 10390184                      0                      0                      0
# 10390185                      0                      0                      0
# 10390186                      0                      0                      0
# 10390187                      0                      0                      0
# 10390188                      0                      0                      0
#
#           Operating_Airline _YV  Operating_Airline _YX  Operating_Airline _ZW
# 0                             0                      0                      0
# 1                             0                      0                      0
# 2                             0                      0                      0
# 3                             0                      0                      0
# 4                             0                      0                      0
# ...                         ...                    ...                    ...
# 10390184                      0                      1                      0
# 10390185                      0                      1                      0
# 10390186                      0                      1                      0
# 10390187                      0                      1                      0
# 10390188                      0                      1                      0
#
# [10390189 rows x 45 columns]

# %%
# Generate our categorical variable lists
flights_cat = flights_df.dtypes[flights_df.dtypes == "object"].index.tolist()

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(flights_df[flights_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(flights_cat)
encode_df.head()

# %%
# Features and target arrays
y = flights_df.Is_Delayed
X = flights_df.drop(columns=["Is_Delayed"])
