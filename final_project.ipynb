# %% [markdown]
# ### ETL - Loading Data

# %%
import sqlalchemy as sql

# %%
#Loading data from Amazon´s Bucket into postgres
engine=sql.create_engine('postgresql://postgres:postgres@flights.cqlftqf6eowc.us-east-2.rds.amazonaws.com:5432/postgres')
#engine=sql.create_engine('postgresql://postgres:postgres@flights3.cqlftqf6eowc.us-east-2.rds.amazonaws.com:5432/postgres')

# %%
import pandas as pd

# %%
#January21, exporting data from CSV
january21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/flights_2021.csv')
january21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        1      1           2          6  2021-01-02
# 1       2021        1      1           3          7  2021-01-03
# 2       2021        1      1           4          1  2021-01-04
# 3       2021        1      1           7          4  2021-01-07
# 4       2021        1      1           8          5  2021-01-08
# ...      ...      ...    ...         ...        ...         ...
# 379379  2021        1      1          30          6  2021-01-30
# 379380  2021        1      1          30          6  2021-01-30
# 379381  2021        1      1          31          7  2021-01-31
# 379382  2021        1      1          31          7  2021-01-31
# ...

# %%
#Febrero21
february21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2021_2.csv')
february21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        1      2          19          5  2021-02-19
# 1       2021        1      2          21          7  2021-02-21
# 2       2021        1      2          22          1  2021-02-22
# 3       2021        1      2          25          4  2021-02-25
# 4       2021        1      2          26          5  2021-02-26
# ...      ...      ...    ...         ...        ...         ...
# 350165  2021        1      2          11          4  2021-02-11
# 350166  2021        1      2          12          5  2021-02-12
# 350167  2021        1      2          14          7  2021-02-14
# 350168  2021        1      2          15          1  2021-02-15
# ...

# %%
#marzo21
march21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2021_3.csv')
march21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        1      3           3          3  2021-03-03
# 1       2021        1      3           3          3  2021-03-03
# 2       2021        1      3           3          3  2021-03-03
# 3       2021        1      3           3          3  2021-03-03
# 4       2021        1      3           3          3  2021-03-03
# ...      ...      ...    ...         ...        ...         ...
# 467121  2021        1      3           3          3  2021-03-03
# 467122  2021        1      3           3          3  2021-03-03
# 467123  2021        1      3           3          3  2021-03-03
# ...

# %%
#abril21
april21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2021_4.csv')
april21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        2      4           5          1  2021-04-05
# 1       2021        2      4           6          2  2021-04-06
# 2       2021        2      4           7          3  2021-04-07
# 3       2021        2      4           8          4  2021-04-08
# 4       2021        2      4           9          5  2021-04-09
# ...      ...      ...    ...         ...        ...         ...
# 473931  2021        2      4          30          5  2021-04-30
# 473932  2021        2      4          30          5  2021-04-30
# 473933  2021        2      4          30          5  2021-04-30
# ...

# %%
#mayo21
may21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2021_5.csv')
may21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        2      5           2          7  2021-05-02
# 1       2021        2      5           2          7  2021-05-02
# 2       2021        2      5           2          7  2021-05-02
# 3       2021        2      5           2          7  2021-05-02
# 4       2021        2      5           2          7  2021-05-02
# ...      ...      ...    ...         ...        ...         ...
# 520054  2021        2      5           2          7  2021-05-02
# 520055  2021        2      5           2          7  2021-05-02
# 520056  2021        2      5           2          7  2021-05-02
# ...

# %%
#junio21
june21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2021_6.csv')
june21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        2      6           1          2  2021-06-01
# 1       2021        2      6           1          2  2021-06-01
# 2       2021        2      6           1          2  2021-06-01
# 3       2021        2      6           1          2  2021-06-01
# 4       2021        2      6           1          2  2021-06-01
# ...      ...      ...    ...         ...        ...         ...
# 573774  2021        2      6           1          2  2021-06-01
# 573775  2021        2      6           1          2  2021-06-01
# 573776  2021        2      6           1          2  2021-06-01
# ...

# %%
#july21
july21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2021_7.csv')
july21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        3      7           3          6  2021-07-03
# 1       2021        3      7           3          6  2021-07-03
# 2       2021        3      7           3          6  2021-07-03
# 3       2021        3      7           3          6  2021-07-03
# 4       2021        3      7           2          5  2021-07-02
# ...      ...      ...    ...         ...        ...         ...
# 615698  2021        3      7          12          1  2021-07-12
# 615699  2021        3      7          13          2  2021-07-13
# 615700  2021        3      7          14          3  2021-07-14
# ...

# %%
#august21
august21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2021_8.csv')
august21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,57,78,85,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        3      8          15          7  2021-08-15
# 1       2021        3      8          15          7  2021-08-15
# 2       2021        3      8          15          7  2021-08-15
# 3       2021        3      8          15          7  2021-08-15
# 4       2021        3      8          15          7  2021-08-15
# ...      ...      ...    ...         ...        ...         ...
# 611489  2021        3      8          29          7  2021-08-29
# 611490  2021        3      8          29          7  2021-08-29
# 611491  2021        3      8          29          7  2021-08-29
# ...

# %%
#september21
september21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2021_9.csv')
september21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,57,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        3      9          15          3  2021-09-15
# 1       2021        3      9          15          3  2021-09-15
# 2       2021        3      9          15          3  2021-09-15
# 3       2021        3      9          15          3  2021-09-15
# 4       2021        3      9          15          3  2021-09-15
# ...      ...      ...    ...         ...        ...         ...
# 567911  2021        3      9          29          3  2021-09-29
# 567912  2021        3      9          30          4  2021-09-30
# 567913  2021        3      9          10          5  2021-09-10
# 567914  2021        3      9          23          4  2021-09-23
# ...

# %%
#october21
october21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2021_10.csv')
october21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,57,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        4     10           1          5  2021-10-01
# 1       2021        4     10           3          7  2021-10-03
# 2       2021        4     10           4          1  2021-10-04
# 3       2021        4     10           5          2  2021-10-05
# 4       2021        4     10           6          3  2021-10-06
# ...      ...      ...    ...         ...        ...         ...
# 595368  2021        4     10           3          7  2021-10-03
# 595369  2021        4     10           3          7  2021-10-03
# 595370  2021        4     10           3          7  2021-10-03
# 595371  2021        4     10           3          7  2021-10-03
# ...

# %%
#november21
november21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2021_11.csv')
november21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,57,86) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        4     11          17          3  2021-11-17
# 1       2021        4     11          17          3  2021-11-17
# 2       2021        4     11          17          3  2021-11-17
# 3       2021        4     11          17          3  2021-11-17
# 4       2021        4     11          17          3  2021-11-17
# ...      ...      ...    ...         ...        ...         ...
# 576688  2021        4     11          17          3  2021-11-17
# 576689  2021        4     11          17          3  2021-11-17
# 576690  2021        4     11          17          3  2021-11-17
# 576691  2021        4     11          17          3  2021-11-17
# ...

# %%
#december21
december21_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2021_12.csv')
december21_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        4     12          12          7  2021-12-12
# 1       2021        4     12          12          7  2021-12-12
# 2       2021        4     12          12          7  2021-12-12
# 3       2021        4     12          12          7  2021-12-12
# 4       2021        4     12          12          7  2021-12-12
# ...      ...      ...    ...         ...        ...         ...
# 580233  2021        4     12          12          7  2021-12-12
# 580234  2021        4     12          12          7  2021-12-12
# 580235  2021        4     12          12          7  2021-12-12
# 580236  2021        4     12          12          7  2021-12-12
# ...

# %%
#january22
january22_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2022_1.csv')
january22_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,78,85,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2022        1      1           6          4  2022-01-06
# 1       2022        1      1           6          4  2022-01-06
# 2       2022        1      1           6          4  2022-01-06
# 3       2022        1      1           6          4  2022-01-06
# 4       2022        1      1           6          4  2022-01-06
# ...      ...      ...    ...         ...        ...         ...
# 563732  2022        1      1          24          1  2022-01-24
# 563733  2022        1      1          24          1  2022-01-24
# 563734  2022        1      1          24          1  2022-01-24
# 563735  2022        1      1          24          1  2022-01-24
# ...

# %%
#february22
february22_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2022_2.csv')
february22_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,78,85,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2022        1      2          28          1  2022-02-28
# 1       2022        1      2          28          1  2022-02-28
# 2       2022        1      2          28          1  2022-02-28
# 3       2022        1      2          28          1  2022-02-28
# 4       2022        1      2          28          1  2022-02-28
# ...      ...      ...    ...         ...        ...         ...
# 519947  2022        1      2          25          5  2022-02-25
# 519948  2022        1      2          23          3  2022-02-23
# 519949  2022        1      2          22          2  2022-02-22
# 519950  2022        1      2          16          3  2022-02-16
# ...

# %%
#march22
march22_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2022_3.csv')
march22_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,86,93,94) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2022        1      3           8          2  2022-03-08
# 1       2022        1      3          12          6  2022-03-12
# 2       2022        1      3          15          2  2022-03-15
# 3       2022        1      3          19          6  2022-03-19
# 4       2022        1      3          22          2  2022-03-22
# ...      ...      ...    ...         ...        ...         ...
# 590537  2022        1      3          31          4  2022-03-31
# 590538  2022        1      3          17          4  2022-03-17
# 590539  2022        1      3           8          2  2022-03-08
# 590540  2022        1      3          25          5  2022-03-25
# ...

# %%
#april22
april22_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2022_4.csv')
april22_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2022        2      4           4          1  2022-04-04
# 1       2022        2      4           4          1  2022-04-04
# 2       2022        2      4           4          1  2022-04-04
# 3       2022        2      4           4          1  2022-04-04
# 4       2022        2      4           4          1  2022-04-04
# ...      ...      ...    ...         ...        ...         ...
# 580285  2022        2      4           4          1  2022-04-04
# 580286  2022        2      4           4          1  2022-04-04
# 580287  2022        2      4           4          1  2022-04-04
# 580288  2022        2      4           4          1  2022-04-04
# ...

# %%
#may22
may22_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2022_5.csv')
may22_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2022        2      5           3          2  2022-05-03
# 1       2022        2      5           4          3  2022-05-04
# 2       2022        2      5           1          7  2022-05-01
# 3       2022        2      5           2          1  2022-05-02
# 4       2022        2      5           3          2  2022-05-03
# ...      ...      ...    ...         ...        ...         ...
# 602945  2022        2      5          29          7  2022-05-29
# 602946  2022        2      5          29          7  2022-05-29
# 602947  2022        2      5          29          7  2022-05-29
# 602948  2022        2      5          29          7  2022-05-29
# ...

# %%
#june22
june22_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2022_6.csv')
june22_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,85,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2022        2      6          27          1  2022-06-27
# 1       2022        2      6          28          2  2022-06-28
# 2       2022        2      6          29          3  2022-06-29
# 3       2022        2      6          30          4  2022-06-30
# 4       2022        2      6           1          3  2022-06-01
# ...      ...      ...    ...         ...        ...         ...
# 602052  2022        2      6          21          2  2022-06-21
# 602053  2022        2      6          21          2  2022-06-21
# 602054  2022        2      6          22          3  2022-06-22
# 602055  2022        2      6          22          3  2022-06-22
# ...

# %%
#July22
july22_df=pd.read_csv('https://flightsproject.s3.us-east-2.amazonaws.com/Flights_2022_7.csv')
july22_df
# Out:
# C:\Users\luis_\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (11,13,86,93) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2022        3      7          19          2  2022-07-19
# 1       2022        3      7          20          3  2022-07-20
# 2       2022        3      7          21          4  2022-07-21
# 3       2022        3      7          24          7  2022-07-24
# 4       2022        3      7          25          1  2022-07-25
# ...      ...      ...    ...         ...        ...         ...
# 618785  2022        3      7           1          5  2022-07-01
# 618786  2022        3      7           1          5  2022-07-01
# 618787  2022        3      7           1          5  2022-07-01
# 618788  2022        3      7           1          5  2022-07-01
# ...

# %%
#importing csv into SQL
january21_df.to_sql('january21', con=engine, index=False, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3255         try:
# -> 3256             return fn()
#    3257         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ...

# %%
february21_df.to_sql('february21', con=engine, index=False, if_exists='replace')

# %%
march21_df.to_sql('march21', con=engine, index=False, if_exists='replace')

# %%
april21_df.to_sql('april21', con=engine, index=False, if_exists='replace')

# %%
may21_df.to_sql('may21', con=engine, index=False, if_exists='replace')

# %%
june21_df.to_sql('june21', con=engine, index=False, if_exists='replace')

# %%
july21_df.to_sql('july21', con=engine, index=False, if_exists='replace')

# %%
august21_df.to_sql('august21', con=engine, index=False, if_exists='replace')

# %%
september21_df.to_sql('september21', con=engine, index=False, if_exists='replace')

# %%
october21_df.to_sql('october21', con=engine, index=False, if_exists='replace')

# %%
november21_df.to_sql('november21', con=engine, index=False, if_exists='replace')

# %%
december21_df.to_sql('december21', con=engine, index=False, if_exists='replace')

# %%
january22_df.to_sql('january22', con=engine, index=False, if_exists='replace')

# %%
february22_df.to_sql('february22', con=engine, index=False, if_exists='replace')

# %%
march22_df.to_sql('march22', con=engine, index=False, if_exists='replace')

# %%
april22_df.to_sql('april22', con=engine, index=False, if_exists='replace')

# %%
may22_df.to_sql('may22', con=engine, index=False, if_exists='replace')

# %%
june22_df.to_sql('june22', con=engine, index=False, if_exists='replace')

# %%
july22_df.to_sql('july22', con=engine, index=False, if_exists='replace')

# %%
flights = pd.concat([january21_df, february21_df, march21_df, april21_df, may21_df, june21_df, july21_df, august21_df, september21_df, october21_df, november21_df, december21_df, january22_df, february22_df, march22_df, april22_df, may22_df, june22_df, july22_df])

# %%
flights
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2021        1      1           2          6  2021-01-02
# 1       2021        1      1           3          7  2021-01-03
# 2       2021        1      1           4          1  2021-01-04
# 3       2021        1      1           7          4  2021-01-07
# 4       2021        1      1           8          5  2021-01-08
# ...      ...      ...    ...         ...        ...         ...
# 618785  2022        3      7           1          5  2022-07-01
# 618786  2022        3      7           1          5  2022-07-01
# 618787  2022        3      7           1          5  2022-07-01
# 618788  2022        3      7           1          5  2022-07-01
# 618789  2022        3      7           1          5  2022-07-01
#
#        Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                             DL                            DL_CODESHARE
# ...

# %%
#importing csv into SQL
flights.to_sql('flights', con=engine, index=False, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1708             context = constructor(
# -> 1709                 dialect, self, conn, execution_options, *args, **kw
#    1710             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in _init_compiled(cls, dialect, connection, dbapi_connection, execution_options, compiled, parameters, invoked_statement, extracted_parameters, cache_hit)
#    1000                 )
# -> 1001                 for grp, m in enumerate(parameters)
#    1002             ]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in <listcomp>(.0)
#    1000                 )
# ...
